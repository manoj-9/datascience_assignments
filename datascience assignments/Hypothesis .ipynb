# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('/content/BuyerRatio (1).csv')

# %%
df
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
df=df.drop('Observed Values',axis=1)

# %%
df
# Out:
#    East  West  North  South
# 0    50   142    131     70
# 1   435  1523   1356    750

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy.stats import f_oneway
from scipy.stats import chi2_contingency
from statsmodels.formula.api import ols
import warnings
warnings.filterwarnings( "ignore" )

# %%
import scipy.stats as stats
stats.ttest_1samp(a=df,popmean=310)
# Out:
# TtestResult(statistic=array([-0.35064935,  0.75669804,  0.7077551 ,  0.29411765]), pvalue=array([0.78529795, 0.5876142 , 0.60789838, 0.817894  ]), df=array([1, 1, 1, 1]))

# %%
class1=df.East
class2=df.West
print(np.var(class1), np.var(class2))
# Out:
# 37056.25 476790.25

# %%
ratio_check = np.var(class2)/np.var(class1)

print(ratio_check)
# Out:
# 12.86666216899983

# %%
print(stats.ttest_ind(a=class1, b=class2, equal_var=True))
# Out:
# Ttest_indResult(statistic=-0.82306722896822, pvalue=0.4969913379002262)
