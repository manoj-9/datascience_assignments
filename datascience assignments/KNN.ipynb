# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('/content/glass (1).csv')
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
df.dtypes
# Out:
# RI      float64
# Na      float64
# Mg      float64
# Al      float64
# Si      float64
# K       float64
# Ca      float64
# Ba      float64
# Fe      float64
# Type      int64
# dtype: object

# %%
x=df[['RI','Na','Mg','Al','Si','K','Ca','Ba','Fe']]
y=df['Type']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33,
random_state=42)

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (143, 9)
# (71, 9)
# (143,)
# (71,)

# %%
#Predicting the test set result
y_pred= knn.predict(x_test)
y_pred
# Out:
# array([1, 7, 1, 7, 2, 2, 1, 2, 2, 1, 5, 5, 2, 2, 6, 5, 6, 1, 1, 6, 2, 7,
#        7, 7, 1, 2, 1, 1, 5, 1, 2, 2, 3, 2, 1, 7, 5, 3, 1, 2, 2, 7, 3, 2,
#        3, 6, 6, 7, 6, 1, 1, 1, 1, 2, 3, 1, 7, 2, 5, 1, 2, 2, 1, 7, 2, 2,
#        1, 6, 2, 1, 1])

# %%
y.value_counts()
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type, dtype: int64

# %%
#Creating the Confusion matrix
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[18,  2,  2,  0,  0,  0],
#        [ 3, 17,  0,  0,  4,  1],
#        [ 1,  0,  3,  0,  0,  0],
#        [ 0,  1,  0,  5,  0,  0],
#        [ 0,  1,  0,  1,  2,  0],
#        [ 0,  0,  0,  0,  1,  9]])

# %%
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score
print ('Accuracy:', accuracy_score(y_test, y_pred))
print ('\n clasification report:\n', classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7605633802816901
#
#  clasification report:
#                precision    recall  f1-score   support
#
#            1       0.82      0.82      0.82        22
#            2       0.81      0.68      0.74        25
#            3       0.60      0.75      0.67         4
#            5       0.83      0.83      0.83         6
#            6       0.29      0.50      0.36         4
#            7       0.90      0.90      0.90        10
#
#     accuracy                           0.76        71
#    macro avg       0.71      0.75      0.72        71
# weighted avg       0.79      0.76      0.77        71
